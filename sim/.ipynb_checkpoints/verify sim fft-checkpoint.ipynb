# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.concatenate((1023*np.ones(8, dtype='int16'), 
                    -1022*np.ones(8, dtype='int16')))
x = np.concatenate((x, x))

# %%
plt.plot(x, 'x-')
plt.title("input")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'input')

# %%
def plot_complex(X, ax, title):
    re = ax.plot(np.real(X), 'x-', label='real')
    im = ax.plot(np.imag(X), 'x-', label='imag')
    ax.legend()
    ax.set_title(title)
    return re, im

# %% [markdown]
# ## numpy output

# %%
X = np.fft.fft(x)

# %%
fig, ax = plt.subplots()
plot_complex(X, ax, "expected out")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.lines.Line2D at 0x7f4ce03b81c0>],
#  [<matplotlib.lines.Line2D at 0x7f4ce02dcc10>])

# %% [markdown]
# ## sim output

# %%
# https://stackoverflow.com/questions/6727875/hex-string-to-signed-int-in-python-3-2
def to_int(hexstr, bits):
    value = int(hexstr, 16)
    if value & (1 << (bits - 1)):
        value -= 1 << bits
    return value
    
    
out = np.loadtxt("../fpga/simulation/modelsim/rom/fft_test_out.memh",
                 dtype='complex',
                 converters={0:lambda s: to_int(s[0:4], 16) + 1j*to_int(s[4:8], 16)})

# %%
fig, ax = plt.subplots()
plot_complex(out, ax, "real out")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.lines.Line2D at 0x7f4ce0383a90>],
#  [<matplotlib.lines.Line2D at 0x7f4ce0380ca0>])

# %% [markdown]
# ## Real output

# %%
out = np.loadtxt("out.memh",
                 dtype='complex',
                 converters={0:lambda s: to_int(s[0:4], 16) + 1j*to_int(s[4:8], 16)})

fig, ax = plt.subplots()
plot_complex(out[0:15], ax, "output")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.lines.Line2D at 0x7f4ce0e82cd0>],
#  [<matplotlib.lines.Line2D at 0x7f4ce05d71c0>])

# %%
np.argmax(np.abs(out[0:15]))
# Out:
# 12

# %%
n = np.arange(32)
t = n / 44e3 # sr
freq = 7989
x = np.sin(2*np.pi*t*freq)

# %%
X = np.fft.fft(x)

# %%
fig, ax = plt.subplots()
plot_complex(X[0:15], ax, "output")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.lines.Line2D at 0x7f4ce06570d0>],
#  [<matplotlib.lines.Line2D at 0x7f4ce0ca9790>])

# %%
np.argmax(np.abs(X[0:15]))
# Out:
# 6
